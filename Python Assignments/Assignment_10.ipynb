# %%
# Salvatore D'Acunto | Joe Heesacker | Jenna Swanson | Terrence White - Assignment 10

import pandas as pd

df = pd.read_excel('Medicare_Provider_Charge_Inpatient_DRGALL_FY2016.xlsx', skiprows=5)

df.head()
# Out:
#                                       DRG Definition  Provider Id  \
# 0  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        10033
# 1  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        30103
# 2  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        40114
# 3  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        50025
# 4  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        50100
#
#                                        Provider Name  \
# 0                     UNIVERSITY OF ALABAMA HOSPITAL
# 1                               MAYO CLINIC HOSPITAL
# 2          BAPTIST HEALTH MEDICAL CENTER-LITTLE ROCK
# 3  UC SAN DIEGO HEALTH HILLCREST - HILLCREST MED CTR
# 4                            SHARP MEMORIAL HOSPITAL
#
#        Provider Street Address Provider City Provider State  \
# 0        619 SOUTH 19TH STREET    BIRMINGHAM             AL
# 1     5777 EAST MAYO BOULEVARD       PHOENIX             AZ
# 2  9601 INTERSTATE 630, EXIT 7   LITTLE ROCK             AR
# ...

# %%
# Number of Unique Hospitals

print(len(df['Provider Name'].unique()))
# Out:
# 3099

# %%
### Number of Unique Hospitals in AR & AK

arak = df[df['Provider State'].isin(['AR', 'AK'])]
print(len(arak['Provider Name'].unique()))
# Out:
# 51

# %%
# Average cost of DRG 001 in FL at each of the 5 hospitals

fl = df[df['Provider State'].isin(['FL'])]
fl001 = fl[fl['DRG Definition'].isin(['001 - HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM W MCC'])]
avg_cost_001 = fl001[['Provider Name', 'Average Total Payments']]
avg_cost_001
# Out:
#                 Provider Name  Average Total Payments
# 14           FLORIDA HOSPITAL           189464.000000
# 15  JACKSON MEMORIAL HOSPITAL           301640.466667
# 16  UF HEALTH SHANDS HOSPITAL           211545.133333
# 17     TAMPA GENERAL HOSPITAL           198471.083333
# 18                MAYO CLINIC           321528.100000
